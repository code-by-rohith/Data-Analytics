# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 62

# %%
x= random.rand(5)
print(x)
# Out:
# [0.00377843 0.72628514 0.07621387 0.23884392 0.36403546]

# %%
x=random.rand(5,8)
print(x)
# Out:
# [[0.14391004 0.54053848 0.80394116 0.55415271 0.34228421 0.55674267
#   0.26945156 0.34524328]
#  [0.30315474 0.24895239 0.15834329 0.53185892 0.81430033 0.38418544
#   0.12136821 0.03179385]
#  [0.98975577 0.84677041 0.63068732 0.80133754 0.36778027 0.26556207
#   0.75347862 0.19608285]
#  [0.97447694 0.50544406 0.93930648 0.94959873 0.45362763 0.90248084
#   0.88621492 0.35727376]
#  [0.84943914 0.47483368 0.71888271 0.92070457 0.39888014 0.56859787
#   0.48718393 0.14180652]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(5, 8)
for row in x:
    plt.plot(row)

plt.title("Sample")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
x= random.randint(100,size=(5,8))
print(x)
# Out:
# [[66 65 14 20 46  7 39 62]
#  [54 41 87 64 94  6 94 35]
#  [91 88 44 41 59 73 72 63]
#  [30  8  1 63 21 55  7 14]
#  [95 64 11 81  0 77 99 65]]

# %%
print(np.random.rand(2, 3, 4))
# Out:
# [[[0.89518341 0.74996198 0.62510151 0.90651573]
#   [0.52039765 0.0671881  0.8090714  0.26472953]
#   [0.46422287 0.16778456 0.50710225 0.85096612]]
#
#  [[0.95181584 0.0041898  0.69477499 0.82994108]
#   [0.85960412 0.67849811 0.84223325 0.52028477]
#   [0.53625322 0.37386287 0.59774729 0.61472881]]]

# %%
from numpy import*
x=random.randint(3,size=(5,8))
print(x)
# Out:
# [[0 2 1 0 2 1 2 1]
#  [1 2 0 0 2 0 0 1]
#  [0 0 1 0 0 1 2 2]
#  [0 2 0 1 1 1 0 1]
#  [2 0 2 1 2 0 1 2]]

# %%
from random import random

lst = [random() for i in range(6)]

print(lst)
# Out:
# [0.40631538556655, 0.9923732800798498, 0.36710398841501457, 0.06274423762180059, 0.6880320008410402, 0.9771479223595838]

# %%
print(np.random.randint(0, 2, size=(3, 3), dtype=bool))
# Out:
# [[ True  True  True]
#  [ True  True False]
#  [ True  True  True]]

# %% [markdown]
#  random floats with specified mean and standard deviation

# %%
mean = 10
std_dev = 2
print(mean + np.random.rand(5) * std_dev)
# Out:
# [11.17223596 11.08935333 11.49614843 10.28643773 11.46492265]
