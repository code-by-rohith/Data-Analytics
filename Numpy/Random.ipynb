# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 7

# %%
x= random.rand(5)
print(x)
# Out:
# [0.13044028 0.67316353 0.73277043 0.49886202 0.31962959]

# %%
x=random.rand(5,8)
print(x)
# Out:
# [[0.18188439 0.14995847 0.36574504 0.3730207  0.79192293 0.30528202
#   0.42428419 0.23276932]
#  [0.16672154 0.40615158 0.41562927 0.18992267 0.34156925 0.55813912
#   0.38396206 0.07209358]
#  [0.26658143 0.73411459 0.49515494 0.51020651 0.57192782 0.48113374
#   0.19496076 0.93986853]
#  [0.60481273 0.89788131 0.75074427 0.48100349 0.78743901 0.75918073
#   0.1829377  0.19730131]
#  [0.72840296 0.19797391 0.81943258 0.59147451 0.34020511 0.15107903
#   0.32272995 0.10472018]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(5, 8)
for row in x:
    plt.plot(row)

plt.title("Sample")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
x= random.randint(100,size=(5,8))
print(x)
# Out:
# [[18 28 84 43 41 83 79 97]
#  [90 26 77  4 38 23  9 64]
#  [10 10 86 35  2 25 77 55]
#  [ 1  2 76  6 46 32 19 85]
#  [93 65 10  5 96 82 24 91]]

# %%
print(np.random.rand(2, 3, 4))
# Out:
# [[[0.86930723 0.62164891 0.66436868 0.04846841]
#   [0.39370731 0.18714051 0.51672648 0.77057277]
#   [0.94173214 0.01810178 0.95996938 0.16291834]]
#
#  [[0.22022263 0.95345703 0.3421935  0.58640672]
#   [0.66544299 0.75002945 0.68985022 0.50610068]
#   [0.87022188 0.06723656 0.72323054 0.66110259]]]

# %%
from numpy import*
x=random.randint(3,size=(5,8))
print(x)
# Out:
# [[2 1 0 1 1 1 2 2]
#  [1 2 0 2 1 1 2 1]
#  [2 2 1 0 1 2 2 2]
#  [2 2 0 2 1 2 0 1]
#  [2 2 2 1 1 2 2 0]]

# %%
from random import random

lst = [random() for i in range(6)]

print(lst)
# Out:
# [0.5760684503093487, 0.45015709606087206, 0.4601318123032163, 0.26418980640099476, 0.18900945270453107, 0.3523946431416711]

# %%
print(np.random.randint(0, 2, size=(3, 3), dtype=bool))
# Out:
# [[ True  True False]
#  [False False  True]
#  [ True False  True]]

# %% [markdown]
#  random floats with specified mean and standard deviation

# %%
mean = 10
std_dev = 2
a=mean + np.random.rand(5) * std_dev
plt.plot(a,marker='o')
plt.show()

# %%
from numpy import random

x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# 7

# %%
x=random.choice([x for x in range(15) ],size=(6,2))
print(x)
# Out:
# [[ 9 13]
#  [ 3 11]
#  [ 7 12]
#  [ 1  7]
#  [10  5]
#  [ 9  4]]

# %%
x=random.choice([5,8,9,10],p=[0.5,0.1,0.4,0],size=(100))
print(x)
# Out:
# [8 9 5 9 8 5 5 5 5 9 5 9 5 9 8 5 9 9 5 9 9 5 5 9 9 5 5 5 5 9 5 5 5 5 9 5 9
#  5 9 5 5 9 9 8 9 9 9 5 5 9 9 9 5 9 5 9 5 5 9 9 5 9 8 5 9 9 9 9 5 5 5 5 5 5
#  5 5 8 9 5 5 5 9 5 9 5 9 9 9 5 9 5 9 5 9 9 9 9 5 9 5]
